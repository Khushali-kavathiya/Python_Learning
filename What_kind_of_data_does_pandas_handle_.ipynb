# %% [markdown]
# <a href="https://colab.research.google.com/github/Khushali-kavathiya/Python_Learning/blob/main/What_kind_of_data_does_pandas_handle_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.DataFrame(
    {
        "Name": ["khushi, miss. kavathiya",
                 "riya, miss. hirapara",
                 "daval, mr. raval"
                ],
        "Age": [22, 21, 19],
        "sex": ["female", "female", "male"]
    }
)

# %%
df
# Out:
#                       Name  Age     sex
# 0  khushi, miss. kavathiya   22  female
# 1     riya, miss. hirapara   21  female
# 2         daval, mr. raval   19    male

# %% [markdown]
# We are interestend in working with the data in the Age column.

# %%
df["Age"]
# Out:
# 0    22
# 1    21
# 2    19
# Name: Age, dtype: int64

# %% [markdown]
# *Create a series from scratch.*

# %%
ages = pd.Series([22, 35, 58], name="Age")

# %%
ages
# Out:
# 0    22
# 1    35
# 2    58
# Name: Age, dtype: int64

# %% [markdown]
# *We want to know the maximum Age of the passengers.*

# %%
df["Age"].max()
# Out:
# 22

# %% [markdown]
# *Maximum age using the Series.*

# %%
ages.max()
# Out:
# 58

# %% [markdown]
# *We are interested in some basic statistics of numerical data of the data table.*

# %%
df.describe()
# Out:
#              Age
# count   3.000000
# mean   20.666667
# std     1.527525
# min    19.000000
# 25%    20.000000
# 50%    21.000000
# 75%    21.500000
# max    22.000000
